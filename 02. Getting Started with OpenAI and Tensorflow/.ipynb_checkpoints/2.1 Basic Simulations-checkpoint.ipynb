# %% [markdown]
# # Basic Simulations in OpenAI's Gym

# %% [markdown]
# <font size=3.5>
# OpenAI Gym is a toolkit for building, evaluating and comparing RL algorithms. It is
# compatible with algorithms written in any frameworks like TensoFlow, Theano, Keras etc... It
# is simple and easy to comprehend. It makes no assumption about the structure of our agent
# and provides an interface to all RL tasks.
#
# Now, we will see, how to simulate environments in gym.

# %% [markdown]
# ## CartPole Environment

# %% [markdown]
# <font size=3.5> First let us import the OpenAI's Gym library

# %%
import gym

# %% [markdown]
# <font size=3.0> We use the make function for simulating the environment

# %%
env = gym.make('CartPole-v0')

# %% [markdown]
# <font size=3.0> Then, we initialize the environment using reset method

# %%
env.reset()

# %% [markdown]
# <font size=3.0> Now,we can loop for some time steps and render the environment at each step

# %%
for _ in range(1000):
    env.render()
     env.step(env.action_space.sample())

# %% [markdown]
# ## Different Types of Environments

# %% [markdown]
# <font size=3.5> OpenAI gym provides a lot of simulation environments for training, evaluating and
# building our agents. We can check the available environments by either checking their
# website or simply typing the following commands which will list the available environments.

# %%
from gym import envs
print(envs.registry.all())

# %% [markdown]
# ## CarRacing Environment

# %% [markdown]
# <font size=3.0> Since Gym provides different interesting environments, let us simulate a car racing
# environment as shown below,

# %%
import gym
env = gym.make('CarRacing-v0')
env.reset()
for _ in range(1000):
    env.render()
     env.step(env.action_space.sample())
